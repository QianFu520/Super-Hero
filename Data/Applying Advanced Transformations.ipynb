# %%
import numpy as np
import pandas as pd
import os,json

# %%
df_info = pd.read_csv("superhero_info - superhero_info.csv")
print(df_info.info)
df_info.head()
# Out:
# <bound method DataFrame.info of                     Hero|Publisher  Gender               Race Alignment  \
# 0             A-Bomb|Marvel Comics    Male              Human      good
# 1     Abe Sapien|Dark Horse Comics    Male      Icthyo Sapien      good
# 2               Abin Sur|DC Comics    Male            Ungaran      good
# 3        Abomination|Marvel Comics    Male  Human / Radiation       bad
# 4      Absorbing Man|Marvel Comics    Male              Human       bad
# ..                             ...     ...                ...       ...
# 458     Yellowjacket|Marvel Comics    Male              Human      good
# 459  Yellowjacket II|Marvel Comics  Female              Human      good
# 460              Yoda|George Lucas    Male     Yoda's species      good
# 461              Zatanna|DC Comics  Female              Human      good
# 462                 Zoom|DC Comics    Male            Unknown       bad
#
#            Hair color Eye color Skin color  \
# ...

# %%
## separate 'Hero|Publisher'column into "Hero"and "publisher"columns and save the 2 new columns into the dataframe
df_info[['Hero','Publisher']] = df_info['Hero|Publisher'].str.split('|',expand=True)
#drop the original column
df_info = df_info.drop(columns=['Hero|Publisher'])
df_info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %%
#covert the the string column(measurements) into actual dictionaries
## use .str.replace to replace all single quotes
df_info['Measurements'] = df_info['Measurements'].str.replace("'",'"')
## Apply the json.loads to the full column
df_info['Measurements'] = df_info['Measurements'].apply(json.loads)
df_info['Measurements'].head()
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# Name: Measurements, dtype: object

# %%
#unpack the measurements column of dictionaries into separate columns
Hei_wei = df_info['Measurements'].apply(pd.Series)
Hei_wei.head()
# Out:
#      Height    Weight
# 0  203.0 cm  441.0 kg
# 1  191.0 cm   65.0 kg
# 2  185.0 cm   90.0 kg
# 3  203.0 cm  441.0 kg
# 4  193.0 cm  122.0 kg

# %%
#add the Hei_wei dataframe with the original dataframe and drop the measurements column
df_info = pd.concat((df_info, Hei_wei), axis = 1)
df_info = df_info.drop(columns = ['Measurements'])
df_info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher    Height    Weight
# 0         A-Bomb      Marvel Comics  203.0 cm  441.0 kg
# 1     Abe Sapien  Dark Horse Comics  191.0 cm   65.0 kg
# 2       Abin Sur          DC Comics  185.0 cm   90.0 kg
# 3    Abomination      Marvel Comics  203.0 cm  441.0 kg
# 4  Absorbing Man      Marvel Comics  193.0 cm  122.0 kg

# %%
df_info[['Height(cm)','cm']] = df_info['Height'].str.split(' ',expand=True)
#drop the original column
df_info = df_info.drop(columns=['Height'])
df_info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher    Weight Height(cm)  cm
# 0         A-Bomb      Marvel Comics  441.0 kg      203.0  cm
# 1     Abe Sapien  Dark Horse Comics   65.0 kg      191.0  cm
# 2       Abin Sur          DC Comics   90.0 kg      185.0  cm
# 3    Abomination      Marvel Comics  441.0 kg      203.0  cm
# 4  Absorbing Man      Marvel Comics  122.0 kg      193.0  cm

# %%
df_info = df_info.drop(columns=['cm'])
df_info
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color             Hero          Publisher    Weight Height(cm)
# ...

# %%
df_info[['Weight(kg)','kg']] = df_info['Weight'].str.split(' ',expand=True)
#drop the original column
df_info = df_info.drop(columns=['Weight'])
df_info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher Height(cm) Weight(kg)  kg
# 0         A-Bomb      Marvel Comics      203.0      441.0  kg
# 1     Abe Sapien  Dark Horse Comics      191.0       65.0  kg
# 2       Abin Sur          DC Comics      185.0       90.0  kg
# 3    Abomination      Marvel Comics      203.0      441.0  kg
# 4  Absorbing Man      Marvel Comics      193.0      122.0  kg

# %%
df_info = df_info.drop(columns=['kg'])
df_info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher Height(cm) Weight(kg)
# 0         A-Bomb      Marvel Comics      203.0      441.0
# 1     Abe Sapien  Dark Horse Comics      191.0       65.0
# 2       Abin Sur          DC Comics      185.0       90.0
# 3    Abomination      Marvel Comics      203.0      441.0
# 4  Absorbing Man      Marvel Comics      193.0      122.0

# %%
df_info = df_info.reindex(columns=['Hero', 'Publisher', 'Gender', 'Eye color', 'Race', 'Hair color', 'Height(cm)', 'Weight(kg)','Skin color', 'Alignment'])
df_info.head()
# Out:
#             Hero          Publisher Gender Eye color               Race  \
# 0         A-Bomb      Marvel Comics   Male    yellow              Human
# 1     Abe Sapien  Dark Horse Comics   Male      blue      Icthyo Sapien
# 2       Abin Sur          DC Comics   Male      blue            Ungaran
# 3    Abomination      Marvel Comics   Male     green  Human / Radiation
# 4  Absorbing Man      Marvel Comics   Male      blue              Human
#
#   Hair color Height(cm) Weight(kg) Skin color Alignment
# 0    No Hair      203.0      441.0    Unknown      good
# 1    No Hair      191.0       65.0       blue      good
# 2    No Hair      185.0       90.0        red      good
# 3    No Hair      203.0      441.0    Unknown       bad
# 4    No Hair      193.0      122.0    Unknown       bad

# %%
df_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Hero        463 non-null    object
#  1   Publisher   463 non-null    object
#  2   Gender      463 non-null    object
#  3   Eye color   463 non-null    object
#  4   Race        463 non-null    object
#  5   Hair color  463 non-null    object
#  6   Height(cm)  463 non-null    object
#  7   Weight(kg)  463 non-null    object
#  8   Skin color  463 non-null    object
#  9   Alignment   463 non-null    object
# dtypes: object(10)
# memory usage: 36.3+ KB

# %%
df_info['Weight(kg)'] = pd.to_numeric(df_info['Weight(kg)'])

# %%
df_info['Height(cm)'] = pd.to_numeric(df_info['Height(cm)'])

# %% [markdown]
# ## part 2: Superhero_powers

# %%
df_power = pd.read_csv('superhero_powers - superhero_powers.csv')
df_power.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
df_power.loc[0, "Powers"]
# Out:
# 'Agility,Super Strength,Stamina,Super Speed'

# %%
def Convert(string):
    li = list(string.split(","))
    return li

# %%
df_power['Powers_split'] = df_power['Powers'].apply(Convert)

# %%
df_power.loc[0, "Powers_split"]
# Out:
# ['Agility', 'Super Strength', 'Stamina', 'Super Speed']

# %%
#check the value counts of the powers column now
df_power['Powers_split'].value_counts()
# Out:
# [Intelligence]                                                                                                                                                                                                                                                                          8
# [Durability, Super Strength]                                                                                                                                                                                                                                                            5
# [Agility, Stealth, Marksmanship, Weapons Master, Stamina]                                                                                                                                                                                                                               4
# ...

# %%
## exploding the column of lists
exploded = df_power.explode('Powers_split')
exploded[['hero_names','Powers','Powers_split']].head(5)
# Out:
#   hero_names                                             Powers  \
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1     A-Bomb  Accelerated Healing,Durability,Longevity,Super...
#
#           Powers_split
# 0              Agility
# 0       Super Strength
# 0              Stamina
# 0          Super Speed
# 1  Accelerated Healing

# %%
## saving the unique values from the exploded column
cols_to_make = exploded['Powers_split'].dropna().unique()
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
# ...

# %%
for col in cols_to_make:
    df_power[col] = df_power['Powers'].str.contains(col)
df_power.head()
# Out:
# C:\Users\qfu88\AppData\Local\Temp\ipykernel_18064\2901467257.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_power[col] = df_power['Powers'].str.contains(col)
# C:\Users\qfu88\AppData\Local\Temp\ipykernel_18064\2901467257.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_power[col] = df_power['Powers'].str.contains(col)
# ...

# %%
df_power.shape
# Out:
# (667, 170)

# %%
df_power = df_power.drop(columns = ['Powers', 'Powers_split'])
df_power.head()
# Out:
#     hero_names  Agility  Super Strength  Stamina  Super Speed  \
# 0      3-D Man     True            True     True         True
# 1       A-Bomb    False            True     True        False
# 2   Abe Sapien     True            True     True        False
# 3     Abin Sur    False           False    False        False
# 4  Abomination    False            True     True         True
#
#    Accelerated Healing  Durability  Longevity  Camouflage  Self-Sustenance  \
# 0                False       False      False       False            False
# 1                 True        True       True        True             True
# 2                 True        True       True       False            False
# 3                False       False      False       False            False
# 4                 True       False      False       False            False
#
#    ...  Weather Control  Omnipresent  Omniscient  Hair Manipulation  \
# 0  ...            False        False       False              False
# ...

# %%
df_power = df_power.set_index('hero_names')
df_power = df_power.reindex(index=df_info['Hero'])
df_power = df_power.reset_index()

# %%
df_power.head()
# Out:
#             Hero  Agility  Super Strength  Stamina  Super Speed  \
# 0         A-Bomb    False            True     True        False
# 1     Abe Sapien     True            True     True        False
# 2       Abin Sur    False           False    False        False
# 3    Abomination    False            True     True         True
# 4  Absorbing Man    False            True    False        False
#
#    Accelerated Healing  Durability  Longevity  Camouflage  Self-Sustenance  \
# 0                 True        True       True        True             True
# 1                 True        True       True       False            False
# 2                False       False      False       False            False
# 3                 True       False      False       False            False
# 4                False        True      False       False            False
#
#    ...  Weather Control  Omnipresent  Omniscient  Hair Manipulation  \
# ...

# %%
final_dataframe = pd.merge(df_info, df_power, left_on="Hero", right_on="Hero", how="inner")
final_dataframe.head()
# Out:
#             Hero          Publisher Gender Eye color               Race  \
# 0         A-Bomb      Marvel Comics   Male    yellow              Human
# 1     Abe Sapien  Dark Horse Comics   Male      blue      Icthyo Sapien
# 2       Abin Sur          DC Comics   Male      blue            Ungaran
# 3    Abomination      Marvel Comics   Male     green  Human / Radiation
# 4  Absorbing Man      Marvel Comics   Male      blue              Human
#
#   Hair color  Height(cm)  Weight(kg) Skin color Alignment  ...  \
# 0    No Hair       203.0       441.0    Unknown      good  ...
# 1    No Hair       191.0        65.0       blue      good  ...
# 2    No Hair       185.0        90.0        red      good  ...
# 3    No Hair       203.0       441.0    Unknown       bad  ...
# 4    No Hair       193.0       122.0    Unknown       bad  ...
#
#    Weather Control  Omnipresent  Omniscient  Hair Manipulation  Nova Force  \
# ...

# %% [markdown]
# ## Use combined DataFrame to answer the following questions.

# %% [markdown]
# Compare the average weight of super powers who have Super Speed to those who do not

# %%
final_dataframe['Super Speed'].value_counts()
# Out:
# False    267
# True     214
# Name: Super Speed, dtype: int64

# %%
final_dataframe.groupby('Super Speed')['Weight(kg)'].mean()
# Out:
# Super Speed
# False    101.449438
# True     126.023364
# Name: Weight(kg), dtype: float64

# %% [markdown]
# As we can see there are more superheros who have the super speed super power than the superheros who don't have the super speed super power. And the average weight of super powers who have super speed is bigger than the average weight of super powers who don't have the super speed.

# %% [markdown]
# What is the average height of heroes for each publisher?

# %%
final_dataframe.groupby('Publisher')['Weight(kg)'].mean()
# Out:
# Publisher
# DC Comics            103.430556
# Dark Horse Comics    101.818182
# George Lucas          77.400000
# Image Comics         405.000000
# Marvel Comics        118.003236
# Shueisha              64.500000
# Star Trek             79.000000
# Team Epic TV          72.000000
# Unknown               83.000000
# Name: Weight(kg), dtype: float64
